# %% [markdown]
# <h1 align="center"><font size="8">Case Study: Bellabeat - Using Python </font></h1>

# %% [markdown]
# # Introduction
#
# This case study is the Capstone Project for the <code>Google Data Analytics</code> Professional Certificate, where <code>the 6 steps of Data Analysis</code> are applied to showcase the analysis.
#
# Title: Bellabeat Case Study
#
# Author: Ratu Aulia Syaharany
#
# Date: 19 December 2024

# %% [markdown]
# ## Bellabeat: How Can A Wellness Technology Company Play It Smart?

# %% [markdown]
# ## Step 1: Ask

# %% [markdown]
# #### 1.0 Background
# Bellabeat is a high-tech manufacturer of beautifully-designed health-focused smart products for women since 2013. Focused on inspiring and empowering women with insights into their health and lifestyle, Bellabeat has experienced rapid growth and established itself as a tech-forward wellness brand for women.
#
# Urška Sršen, the co-founder and Chief Creative Officer, believes that analyzing data from non-Bellabeat consumers (such as FitBit fitness tracker usage) could uncover new growth opportunities.

# %% [markdown]
# #### 1.1 Business Task
# The main goal is to examine data from the FitBit Fitness Tracker App to understand consumer behavior and uncover trends that are relevant to Bellabeat's marketing strategy.

# %% [markdown]
# #### 1.2 Business Objective
# 1. Analyze dominant trends among FitBit users.
# 2. Evaluate how these trends align with Bellabeat's customer demographic.
# 3. Apply the insights gained to refine and enhance Bellabeat's marketing strategy.

# %% [markdown]
# #### 1.3 Deliverables
# 1. A concise overview of the business objective
# 2. A detailed explanation of all data sources utilized
# 3. A record of any data cleaning or transformation processes
# 4. A comprehensive summary of the analysis conducted
# 5. Relevant visualizations and key insights from the findings
# 6. Strategic high-level recommendations derived from the analysis

# %% [markdown]
# #### 1.4 Key Stakeholders
# 1. Urška Sršen: Bellabeat’s cofounder and Chief Creative Officer
# 2. Sando Mur: Mathematician, Bellabeat’s cofounder and key member of the Bellabeat executive team
# 3. Bellabeat marketing analytics team: A team of data analysts guiding Bellabeat's marketing strategy.

# %% [markdown]
# ## Step 2: Prepare

# %% [markdown]
# #### 2.1 Information on Data Source
# 1. The dataset, titled FitBit Fitness Tracker Data, is publicly accessible on Kaggle and contains 18 CSV files.
# 2. It was collected through a survey conducted via Amazon Mechanical Turk between March 12, 2016, and May 12, 2016.
# 3. The dataset features data from 30 FitBit users who agreed to share their personal tracker information.
# 4. The variables in the dataset include details on physical activity duration, heart rate, sleep patterns, daily activity metrics, and step counts.

# %% [markdown]
# #### 2.2 Limitation of Data
# 1. With a sample size of only 30 female FitBit users, it may not adequately represent the larger female population.
# 2. The data collected in 2016 may be outdated and not fully reflective of current consumer behaviors and trends.
# 3. Since the data comes from a survey, its reliability and accuracy cannot be assured.

# %% [markdown]
# #### 2.3 Is Data ROCC?
#
# An ideal data source adheres to the ROCCC principle, representing <code>Reliability</code>, <code>Originality</code>, <code>Comprehensiveness</code>, <code>Currency</code>, and proper <code>Citation</code>.
#
# 1. Reliable - Low: The small sample size of 30 respondents limits the reliability of the data.
# 2. Original - Low: Obtained through a third-party platform, Amazon Mechanical Turk.
# 3. Comprehensive - Medium: The parameters show a moderate alignment with Bellabeat's product offerings.
# 4. Current - Low: The dataset is five years old and might not be applicable to current situations.
# 5. Cited - Low: Data obtained from a third-party platform lacks complete traceability.

# %% [markdown]
# #### 2.4 Data Selection
#
# The dataset chosen for analysis is the <code>daily_activity.csv</code> file.

# %% [markdown]
# ## Step 3: Process
# Python is being used to prepare and process the data.

# %% [markdown]
# #### 3.1 Preparing The Environment
#
# In order to ensure smooth data handling, we have installed and assigned aliases to the following packages:
# 1. <code>NumPy</code>: A fundamental package for numerical computing in Python.
# 2. <code>Pandas</code>: An essential library for data manipulation and analysis.
# 3. <code>Matplotlib</code>: A versatile plotting library for generating visualizations.
# 4. <code>Datetime</code>: A module enabling efficient handling of dates and times in Python.

# %%
# Import the necessary library and alias
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import datetime as dt

# %% [markdown]
# #### 3.2 Importing the Dataset

# %%
# read_csv function to read the required CSV file 
df = pd.read_csv("C:/daily_activity.csv")

# %% [markdown]
# #### 3.3 Data Cleaning and Manipulation
#
# To maintain the integrity and reliability of our analysis, we implement thorough data cleaning and manipulation processes. The steps below detail our approach:
# 1. Observe and Familiarize with Data:
#
#    Conduct a detailed review of the dataset to fully understand its structure, variables, and any potential irregularities.
# 2. Check for Null or Missing Values:
#
#    Conduct a systematic assessment to identify and address any instances of missing or null values within the dataset.
# 3. Conduct a Data Sanity Check:
#
#    Ensure the dataset meets established criteria to confirm its consistency and reliability, including checks for logical coherence and accuracy of data entries.

# %% [markdown]
# We use the `head()` function to preview the first 10 rows of the `daily_activity` dataset, providing an initial understanding of its structure and contents.

# %%
# preview 10 rows of daily_activity table
df.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366     4/1/2016       12262           7.87             7.87
# 8  1503960366     4/2/2016       11248           7.25             7.25
# 9  1503960366     4/3/2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %% [markdown]
# To gather essential details about the `daily_activity` dataset, we can use the `info()` method available in Pandas DataFrame. This method delivers a brief overview of the dataset, including the total number of rows and columns, column names, and the data types of each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %% [markdown]
# To detect null or missing values in the `daily_activity` dataset, we use Pandas' `isnull()` function combined with the `sum()` function. This approach provides a count of null values in each column, enabling us to evaluate the dataset's completeness.

# %%
missing_value = df.isnull().sum()
missing_value[:]
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %% [markdown]
# To ensure the uniqueness of IDs in the <code>daily_activity</code> dataset and verify that there are exactly 30 unique IDs, we can utilize Pandas' <code>unique()</code> function. This function calculates the number of distinct values in a specified column, such as the ID column. By comparing the resulting count of unique IDs to the expected total of 30, we can validate the dataset's integrity.

# %%
unique_id = len(pd.unique(df["Id"]))
print("# of unique Id: " + str(unique_id))
# Out:
# # of unique Id: 35

# %% [markdown]
# Drawing from the observations gathered:
# 1. No typographical errors, null, or missing values were found in the dataset.
# 2. The dataframe consists of 457 rows and 15 columns.
# 3. The `ActivityDate` column is mistakenly categorized as an object dtype and needs to be converted to the `datetime64` dtype to ensure consistency and facilitate easier manipulation.
# 4. An unexpected inconsistency was discovered in the number of unique IDs, showing 35 unique IDs instead of the anticipated 30. This discrepancy requires further examination to determine the cause of the difference.
#
# The specified data manipulations are carried out as follows:
# 1. The `ActivityDate` column is cast to the `datetime64` dtype using the `pd.to_datetime()` function in Pandas.
# 2. The format of the `ActivityDate` column is standardized to yyyy-mm-dd.
# 3. A new column called `TotalMins` is added, which represents the total of `VeryActiveMinutes`, `FairlyActiveMinutes`, `LightlyActiveMinutes`, and `SedentaryMinutes`.
# 4. A new column called `DayOfTheWeek` is generated by extracting the weekday from the `ActivityDate` column to facilitate further analysis.
# 5. An additional column called `TotalHours` is created by converting the `TotalMins` column from minutes to hours.
# 6. The columns are reordered and renamed according to the specified requirements.

# %%
# convert "ActivityDate" to datatime64 dtype and format to yyyy-mm-dd
df["ActivityDate"] = pd.to_datetime(df["ActivityDate"], format="%m/%d/%Y")

# re-print information to confirm
df.info()

# print the first 5 rows of "ActivityDate" to confirm
df["ActivityDate"].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    datetime64[ns]
#  2   DayOfTheWeek              457 non-null    object
#  3   TotalSteps                457 non-null    int64
#  4   TotalDistance             457 non-null    float64
#  5   TrackerDistance           457 non-null    float64
#  6   LoggedActivitiesDistance  457 non-null    float64
#  7   VeryActiveDistance        457 non-null    float64
#  8   ModeratelyActiveDistance  457 non-null    float64
#  9   LightActiveDistance       457 non-null    float64
#  10  SedentaryActiveDistance   457 non-null    float64
#  11  VeryActiveMinutes         457 non-null    int64
#  12  FairlyActiveMinutes       457 non-null    int64
# ...

# %% [markdown]
# We will generate a new list called `DayOfThWeek` with the column names rearranged according to your specifications.

# %%
#r create new list of rearranged columns
new_cols = ['Id', 'ActivityDate', 'DayOfTheWeek', 'TotalSteps', 'TotalDistance', 'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'TotalExerciseMinutes', 'TotalExerciseHours', 'Calories']

# reindex function to rearrange columns based on "new_cols"
df = daily_activity.reindex(columns=new_cols)

# print 1st 5 rows to confirm
df.head(5)
# Out:
#            Id ActivityDate  DayOfTheWeek  TotalSteps  TotalDistance  \
# 0  1503960366    3/25/2016           NaN       11004           7.11
# 1  1503960366    3/26/2016           NaN       17609          11.55
# 2  1503960366    3/27/2016           NaN       12736           8.53
# 3  1503960366    3/28/2016           NaN       13231           8.93
# 4  1503960366    3/29/2016           NaN       12041           7.85
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             7.11                       0.0                2.57
# 1            11.55                       0.0                6.92
# 2             8.53                       0.0                4.66
# 3             8.93                       0.0                3.19
# 4             7.85                       0.0                2.16
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.46                 4.07                      0.0
# ...

# %% [markdown]
# To generate a new column by extracting the day of the week from the `ActivityDate` column for further analysis, we can utilize the `dt.dayofweek` attribute of the datetime object in Pandas. This attribute returns an integer where Monday is 0 and Sunday is 6, representing the day of the week.
#
# We will now create the new column, `DayOfTheWeek`, using this attribute.

# %%
# convert "ActivityDate" to datatime64 dtype and format to yyyy-mm-dd
df["ActivityDate"] = pd.to_datetime(df["ActivityDate"], format="%m/%d/%Y")

# create new column "day_of_the_week" to represent day of the week 
df["DayOfTheWeek"] = df["ActivityDate"].dt.day_name()

# print 1st 5 rows to confirm
df["DayOfTheWeek"].head(5)
# Out:
# 0      Friday
# 1    Saturday
# 2      Sunday
# 3      Monday
# 4     Tuesday
# Name: DayOfTheWeek, dtype: object

# %% [markdown]
# To rearrange and rename columns from the current `XxxYyy` format to the desired `xxx_yyy` format, we will use string manipulation techniques to achieve this transformation. This involves converting column names to lowercase and inserting underscores between words where needed.

# %%
# rename columns
df.rename(columns = {"Id":"id", "ActivityDate":"date", "DayOfTheWeek":"day_of_the_week", "TotalSteps":"total_steps", "TotalDistance":"total_dist", "TrackerDistance":"track_dist", "LoggedActivitiesDistance":"logged_dist", "VeryActiveDistance":"very_active_dist", "ModeratelyActiveDistance":"moderate_active_dist", "LightActiveDistance":"light_active_dist", "SedentaryActiveDistance":"sedentary_active_dist", "VeryActiveMinutes":"very_active_mins", "FairlyActiveMinutes":"fairly_active_mins", "LightlyActiveMinutes":"lightly_active_mins", "SedentaryMinutes":"sedentary_mins", "TotalExerciseMinutes":"total_mins","TotalExerciseHours":"total_hours","Calories":"calories"}, inplace = True)

# print column names to confirm
print(df.columns.values)
df.head(5)
# Out:
# ['id' 'date' 'day_of_the_week' 'total_steps' 'total_dist' 'track_dist'
#  'logged_dist' 'very_active_dist' 'moderate_active_dist'
#  'light_active_dist' 'sedentary_active_dist' 'very_active_mins'
#  'fairly_active_mins' 'lightly_active_mins' 'sedentary_mins' 'total_mins'
#  'total_hours' 'calories']
#            id       date day_of_the_week  total_steps  total_dist  track_dist  \
# 0  1503960366 2016-03-25          Friday        11004        7.11        7.11
# 1  1503960366 2016-03-26        Saturday        17609       11.55       11.55
# 2  1503960366 2016-03-27          Sunday        12736        8.53        8.53
# 3  1503960366 2016-03-28          Monday        13231        8.93        8.93
# 4  1503960366 2016-03-29         Tuesday        12041        7.85        7.85
#
#    logged_dist  very_active_dist  moderate_active_dist  light_active_dist  \
# 0          0.0              2.57                  0.46               4.07
# ...

# %% [markdown]
# To generate a new column called `total_mins`, which represents the total logged time, we will add up the values from the columns `VeryActiveMinutes`, `FairlyActiveMinutes`, `LightlyActiveMinutes`, and `SedentaryMinutes` for each row. This will provide the overall duration of activity in minutes for each entry in the dataset. Let's move forward with this calculation.

# %%
# create new column "totalmins" containing sum of total minutes.
df["total_mins"] = df["very_active_mins"] + df_activity["fairly_active_mins"] + df_activity["lightly_active_mins"] + df_activity["sedentary_mins"]
df["total_mins"].head(5)
# Out:
# 0    1054
# 1     968
# 2     934
# 3    1363
# 4    1062
# Name: total_mins, dtype: int64

# %% [markdown]
# To generate a new column by converting the `total_mins` column, which represents the total time logged in minutes, into hours, we will divide the `total_mins` column by 60 (since 1 hour equals 60 minutes). This will provide the corresponding duration in hours.
#
# Let’s move forward with this calculation to create the new column.

# %%
df['total_hours'] = round(df['total_mins']/60)
df['total_hours'].head()
# Out:
# 0    18.0
# 1    16.0
# 2    16.0
# 3    23.0
# 4    18.0
# Name: total_hours, dtype: float64

# %% [markdown]
# ## Step 4: Analysis

# %% [markdown]
# To begin the analysis, the following statistics will be computed for the df_activity dataset:
#
# - **Count**: The total number of rows in the dataset.
# - **Mean**: The average value for all numerical columns.
# - **Standard Deviation**: A measure of the spread or variability in the data.
# - **Minimum and Maximum**: The smallest and largest values in each numerical column.
# - **Percentiles**: The values below which a specific percentage of observations fall.

# %% [markdown]
# The `describe()` method in Pandas will be used to generate these statistics for the `df` dataset. This method offers a detailed summary of the numerical columns, including count, mean, standard deviation, minimum, percentiles, and maximum values. Let’s calculate these statistics.

# %%
df.describe()
# Out:
#                  id                           date   total_steps  total_dist  \
# count  4.570000e+02                            457    457.000000  457.000000
# mean   4.628595e+09  2016-04-04 04:40:26.258205696   6546.562363    4.663523
# min    1.503960e+09            2016-03-12 00:00:00      0.000000    0.000000
# 25%    2.347168e+09            2016-04-02 00:00:00   1988.000000    1.410000
# 50%    4.057193e+09            2016-04-05 00:00:00   5986.000000    4.090000
# 75%    6.391747e+09            2016-04-08 00:00:00  10198.000000    7.160000
# max    8.877689e+09            2016-04-12 00:00:00  28497.000000   27.530001
# std    2.293781e+09                            NaN   5398.493064    4.082072
#
#        track_dist  logged_dist  very_active_dist  moderate_active_dist  \
# count  457.000000   457.000000        457.000000            457.000000
# mean     4.609847     0.179427          1.180897              0.478643
# ...

# %% [markdown]
# Based on the statistical findings:
#
# - On average, users log 6,546 steps, which is roughly 5.24 kilometers. This is below the recommended 10,000 steps or 8 kilometers per day suggested by the CDC for maintaining optimal health, managing weight, and enhancing fitness.
# - Sedentary behavior seems to be common among users, with an average of 995 minutes, or roughly 20 hours, spent in sedentary activity. This accounts for 81% of the total average minutes recorded.
# - The average calories burned is estimated at 2,189, which is roughly equivalent to 0.62 pounds. It's important to consider that the interpretation of calorie burn can vary greatly depending on factors like age, weight, daily activities, exercise routine, hormonal balance, and daily calorie intake.
#
# These results underscore areas where users might benefit from motivation or interventions to boost physical activity and enhance overall health and well-being.

# %% [markdown]
# ## Step 5: Visualization

# %% [markdown]
# #### 5.1 Data Visualization and Findings
# In this step, we will use data visualization techniques to clearly convey the insights obtained from the analysis. Visualizations are effective tools for simplifying complex data, allowing stakeholders to quickly and intuitively understand key findings.

# %%
# import matplotlib package
import matplotlib.pyplot as plt

# plotting histogram
plt.style.use("default")
plt.figure(figsize=(6,4)) # specify size of the chart
plt.hist(df.day_of_the_week, bins = 7, 
         width = 0.6, color = "pink", edgecolor = "black")

# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Frequency")
plt.title("No. of times users logged in app across the week")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Frequency of Usage Across the Week
#
# This histogram illustrates the frequency of FitBit app usage across different days of the week.
# - Saturday and Sunday are the days with the highest frequency of use. This indicates that users tend to access the app more on weekends. This may be due to more free time or specific activities related to the app on these days.
# - Wednesday recorded the lowest frequency of use.This could be a focal point for further analysis.Was there a specific factor on Wednesday that caused the drop in usage? Perhaps there were other events or activities that attracted more user attention on that day, or there could have been technical issues with the app on that day.

# %%
# import matplotlib package
import matplotlib.pyplot as plt

# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) # specify size of the chart
plt.scatter(df.total_steps, df.calories, 
            alpha = 0.8, c = df.calories)

# add annotations and visuals
median_calories = 2189
median_steps = 6546

plt.colorbar(orientation = "vertical")
plt.axvline(median_steps, color = "Blue", label = "Median steps")
plt.axhline(median_calories, color = "Red", label = "Median calories burned")
plt.xlabel("Steps taken")
plt.ylabel("Calories burned")
plt.title("Calories burned for every step taken")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### Calories Burned for Every Step Taken
# The scatter plot analysis revealed the following insights:
#
# 1. Positive Correlation: There is a clear positive relationship between the number of steps taken
#    and the calories burned.
#
# 2. Intensity Variation: The calories burned intensify as users take more steps, particularly
#    within the range of 0 to 15,000 steps, followed by a gradual decline beyond 15,000 steps.
#
# 3. Outlier Observations:
#    - Instances of zero steps are associated with zero or minimal calories burned, reflecting very
#      low levels of physical activity.
#    - One data point stands out, showing an unusually high calorie burn (> 4000) despite zero
#      steps recorded.
#    - Such outliers could result from natural variations in data, user behavior inconsistencies,
#      or potential inaccuracies in data collection, such as miscalculations, data contamination, or human errors. A deeper investigation may be needed to identify the root causes of these anomalies.

# %%
# import matplotlib package
import matplotlib.pyplot as plt

# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) # Specify size of the chart
plt.scatter(df.total_hours, df.calories, 
            alpha = 0.8, c = df.calories, 
            cmap = "Spectral")

# adding annotations and visuals
median_calories = 2189
median_hours = 19
median_sedentary = 995 / 60

plt.colorbar(orientation = "vertical")
plt.axvline(median_hours, color = "Blue", label = "Median steps")
plt.axvline(median_sedentary, color = "Purple", label = "Median sedentary")
plt.axhline(median_calories, color = "Red", label = "Median hours")
plt.xlabel("Hours logged")
plt.ylabel("Calories burned")
plt.title("Calories burned for every hour logged")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Calories Burned for Every Hour Logged
# The scatter plot analysis reveals the following:
#
# 1. Weak Positive Correlation: A weak positive correlation exists between the number of hours
#    logged and the calories burned. However, this relationship lacks statistical significance, largely due to the influence of sedentary hours (represented by the purple line) concentrated around the 16 to 17-hour range.
# 2. Outlier Identification:
#    - Similar to previous observations, instances of zero values suggest minimal or no calories
#      burned, likely reflecting periods of inactivity.
#    - A notable red data point appears at the 24-hour mark, showing zero calories burned. This
#      irregularity could stem from factors such as natural data variations or potential errors in the data collection process.
#
# These outliers require additional investigation to understand their root causes and potential impact on the analysis.

# %%
# import packages
import matplotlib.pyplot as plt
import numpy as np

# calculating total of individual minutes column
very_active_mins = df["very_active_mins"].sum()
fairly_active_mins = df["fairly_active_mins"].sum()
lightly_active_mins = df["lightly_active_mins"].sum()
sedentary_mins = df["sedentary_mins"].sum()

# plotting pie chart
slices = [very_active_mins, fairly_active_mins, lightly_active_mins, sedentary_mins]
labels = ["Very active minutes", "Fairly active minutes", "Lightly active minutes", "Sedentary minutes"]
colours = ["lightcoral", "pink", "lightskyblue", "lightgreen"]
explode = [0, 0, 0, 0.1]
plt.style.use("default")
plt.pie(slices, labels = labels, 
        colors = colours, wedgeprops = {"edgecolor": "black"}, 
        explode = explode, autopct = "%1.1f%%")
plt.title("Percentage of Activity in Minutes")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Proportion of Activity in Minutes
#
# As observed from the pie chart:
#
# 1. Sedentary minutes make up the highest proportion, accounting for 83.3%.
# 2. This indicates that users mainly use the FitBit app to track routine daily activities, such as
#    commuting, sedentary movements (e.g., moving from one place to another), or running errands.
# 3. The app is rarely used for tracking fitness activities like running, as shown by the small
#    percentages of fairly active (1.1%) and very active (1.4%) activities. This trend is concerning, given that the FitBit app is intended to encourage and support fitness activities.

# %% [markdown]
# ## Step 6: Implementation
#
# In the final phase, we transition from analysis to implementation, where we share our findings and suggest practical recommendations derived from the analysis.
#
# Let’s tackle the main questions and develop actionable insights:
#
# 1. What insights can we derive from the data?
#    - Primarily, users (83.3%) are using the FitBit app to track sedentary activities instead of
#      actively monitoring their health and fitness routines.
#    - A clear trend shows that activity tracking is higher on weekends compared to weekdays,
#      suggesting that users are more likely to use the app on weekends. This could be attributed to having more free time or engaging in specific activities related to the app on these days.
#
# 2. How can these insights be translated to benefit Bellabeat's clientele?
#    - The observed user behaviors align with Bellabeat's target audience, highlighting the need to
#      empower women with detailed health and fitness insights to support informed decision-making.
#
#
# 3. What strategic implications do these insights offer for Bellabeat's marketing approach?
#    - By utilizing these insights, Bellabeat can customize its marketing strategies to highlight
#      the significance of comprehensive health monitoring, incorporating features that motivate consistent physical activity and encourage healthy lifestyle habits.
#    - Taking advantage of the observed weekend activity tracking peak, Bellabeat can strategically
#      launch targeted marketing campaigns.s and engagement initiatives during these periods to maximize user interaction and retention.
